# %%
import pandas as pd

# %% [markdown]
# 1. Carregar os dados do arquivo CSV

# %%
df_school = pd.read_csv("data/3_school_data.csv")

# %% [markdown]
# 2. Calcular a média de cada aluno em todas as disciplinas.

# %%
df_school['Average'] = df_school.loc[:, 'Math':'PhysicalEducation'].mean(axis=1)
df_school[['Name', 'Average']]
# Out:
#       Name  Average
# 0    Alice     80.0
# 1      Bob     84.0
# 2  Charlie     78.0
# 3    David     71.0
# 4      Eve     70.0
# 5    Frank     63.0
# 6    Grace     85.0
# 7   Hannah     54.0
# 8      Ivy     57.0
# 9     Jack     57.0

# %% [markdown]
# 3. Adicionar uma coluna indicando se o aluno está "Aprovado" (média >= 60) ou "Reprovado" (média < 60).

# %%
df_school['Classification'] = ['Approved' if grade >= 60
                               else 'Reproved'
                               for grade in df_school['Average']]
df_school
# Out:
#    StudentID     Name  Math  Science  English  History  PhysicalEducation  \
# 0          1    Alice    80       70       90       60                100
# 1          2      Bob    90       85       80       70                 95
# 2          3  Charlie    85       80       70       65                 90
# 3          4    David    70       60       85       55                 85
# 4          5      Eve    60       55       75       80                 80
# 5          6    Frank    55       50       65       75                 70
# 6          7    Grace    95       90       95       85                 60
# 7          8   Hannah    40       45       50       60                 75
# 8          9      Ivy    50       65       60       45                 65
# 9         10     Jack    65       60       55       50                 55
#
#    Average Classification
# 0     80.0       Approved
# 1     84.0       Approved
# 2     78.0       Approved
# 3     71.0       Approved
# 4     70.0       Approved
# 5     63.0       Approved
# 6     85.0       Approved
# 7     54.0       Reproved
# 8     57.0       Reproved
# 9     57.0       Reproved

# %% [markdown]
# 4. Filtrar apenas os alunos "Reprovados".

# %%
df_school[df_school['Classification'] == 'Reproved']
# Out:
#    StudentID    Name  Math  Science  English  History  PhysicalEducation  \
# 7          8  Hannah    40       45       50       60                 75
# 8          9     Ivy    50       65       60       45                 65
# 9         10    Jack    65       60       55       50                 55
#
#    Average Classification
# 7     54.0       Reproved
# 8     57.0       Reproved
# 9     57.0       Reproved

# %% [markdown]
# 5. Calcular a média por disciplina (Math, Science, English, History, PhysicalEducation) para toda a turma.

# %%
df_school.loc[:, 'Math':'PhysicalEducation'].mean()
# Out:
# Math                 69.0
# Science              66.0
# English              72.5
# History              64.5
# PhysicalEducation    77.5
# dtype: float64

# %% [markdown]
# 6. Encontrar o aluno com a maior média geral.

# %%
df_school.iloc[df_school['Average'].idxmax()]
# Out:
# StudentID                   7
# Name                    Grace
# Math                       95
# Science                    90
# English                    95
# History                    85
# PhysicalEducation          60
# Average                  85.0
# Classification       Approved
# Name: 6, dtype: object

# %% [markdown]
# 7. Adicionar uma coluna com a média ponderada das disciplinas (considere pesos diferentes para cada disciplina, ex.: Math - 2, Science - 1.5, etc.).

# %%
pesos = {
    'Math': 2,
    'Science': 1.5,
    'English': 1.5,
    'History': 1,
    'PhysicalEducation': 1
}

df_school['Weighted_Avg'] = (
    df_school['Math'] * pesos['Math'] +
    df_school['Science'] * pesos['Science'] +
    df_school['English'] * pesos['English'] +
    df_school['History'] * pesos['History'] +
    df_school['PhysicalEducation'] * pesos['PhysicalEducation']
) / sum(pesos.values())

df_school['Weighted_Avg'] = df_school['Weighted_Avg'].round(1)
df_school
# Out:
#    StudentID     Name  Math  Science  English  History  PhysicalEducation  \
# 0          1    Alice    80       70       90       60                100
# 1          2      Bob    90       85       80       70                 95
# 2          3  Charlie    85       80       70       65                 90
# 3          4    David    70       60       85       55                 85
# 4          5      Eve    60       55       75       80                 80
# 5          6    Frank    55       50       65       75                 70
# 6          7    Grace    95       90       95       85                 60
# 7          8   Hannah    40       45       50       60                 75
# 8          9      Ivy    50       65       60       45                 65
# 9         10     Jack    65       60       55       50                 55
#
#    Average Classification  Weighted_Avg
# 0     80.0       Approved          80.0
# 1     84.0       Approved          84.6
# 2     78.0       Approved          78.6
# 3     71.0       Approved          71.1
# 4     70.0       Approved          67.9
# 5     63.0       Approved          61.1
# 6     85.0       Approved          87.5
# 7     54.0       Reproved          51.1
# 8     57.0       Reproved          56.8
# 9     57.0       Reproved          58.2

# %% [markdown]
# 8. Determinar quantos alunos estão "Aprovados" e quantos estão "Reprovados".

# %%
print(f"Aprovados = {int(df_school[df_school['Classification'] == 'Approved']['Classification'].count())}")
print(f"Reprovados = {int(df_school[df_school['Classification'] == 'Reproved']['Classification'].count())}")
# Out:
# Aprovados = 7
# Reprovados = 3

# %% [markdown]
# 9. Salvar o resultado em um novo arquivo CSV.

# %%
df_school.to_csv("data/3_school_data_new.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_survey.to_csv("data/2_survey_data_new.csv")
#
# NameError: name 'df_survey' is not defined
